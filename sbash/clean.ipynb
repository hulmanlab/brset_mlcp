# %%
# Read the file
file_path = '/home/livieymli/brset_analysis/BRSET/sbash/3class/70&70/t_3class_DR_res_eval_70+70.sh-62991888.out'

with open(file_path, 'r') as file:
    file_contents = file.readlines()
    for line in file_contents:             
        if line.startswith('100'):
            # '213/213', '31/31', '62/62', '245/245', '711/711', '306/306', '304/304'
            for st in['924/924', '93/93', '62/62', '245/245', '306/306']:
                if st in line:
                    next_line = file_contents[file_contents.index(line) + 1]
                    if st in next_line:
                        print(next_line, end='')
                        file_contents[file_contents.index(line) + 1] = ''  
                    else:
                        print(line, end='')
        elif line.startswith('Epoch'):
            print(line, end='') 
        elif line.startswith('Early'):
            print(line, end='')
        elif line.startswith('Train'):
            print(line, end='')
        # elif line.startswith('100') and '245/245' in line:
        #     print(line, end='')
