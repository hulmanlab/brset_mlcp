# %% [markdown]
# ### Setup Environment:

# %%
from src.get_dataset import get_dataset

# %% [markdown]
# ### Get the dataset
#
# **Note:** Set download to `True` to download the dataset from pyhsionet into `data/`
#
# it will generate a structure like:
#
# * data/
#     * lables.csv
#     * images/
#         * image_1.jpg
#         * image_2.jpg
#         * image_3.jpg
#
#         ...
#
#         * image_n.jpg

# %%
# Constants:
DATASET = 'data/'
DOWNLOAD = False

# %%
get_dataset("data/", download=DOWNLOAD)
